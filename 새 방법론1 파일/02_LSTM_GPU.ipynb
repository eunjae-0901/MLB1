# %% [markdown]
# # Scenario 2 — 2025-paper LSTM extension (GPU)
#
# 20 x 5-day sequence, event-aware weighted BCE, and auxiliary days-to-IL regression. Requires CUDA.

# %%
# !pip install -r requirements-gpu.txt
# Out:
# 'pip'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# %run 04_train_gpu_models.py --model lstm --seed 42 --epochs 100
# Out:
# model  seed         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2       mcc  regression_mae_days
#  lstm    42 validation_all 24926        2087       0.083728   0.001462 0.601921 0.123488 0.222219  0.679005  0.201637   0.089846 0.934835 0.163936 0.324485  0.057440            26.904921
#  lstm    42       test_all 17838        1875       0.105113   0.001462 0.521172 0.107322 0.255031  0.792290  0.198397   0.107184 0.904000 0.191645 0.363515  0.018873            29.304403
#  lstm    42      test_seen 11169        1131       0.101262   0.001462 0.548760 0.109399 0.245616  0.769086  0.201719   0.104300 0.907162 0.187090 0.357217  0.027364            28.280436
#  lstm    42       test_new  6669         744       0.111561   0.001462 0.472872 0.105954 0.270801  0.831151  0.192833   0.111929 0.899194 0.199078 0.373618  0.003436            30.861006
#  lstm    42   test_bullpen 10947        1042       0.095186   0.001462 0.516569 0.096571 0.241644  0.739147  0.175482   0.094885 0.897313 0.171623 0.333405 -0.003075            29.464085
#  lstm    42   test_starter  6891         833       0.120882   0.001462 0.525018 0.121748 0.276299  0.876712  0.234799   0.127517 0.912365 0.223760 0.408954  0.051493            29.104660

# %%
# %run 04_train_gpu_models.py --model lstm --seed 52 --epochs 100
# Out:
# model  seed         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2      mcc  regression_mae_days
#  lstm    52 validation_all 24926        2087       0.083728   0.253283 0.622333 0.121240 0.226044  0.626147  0.414708   0.104217 0.788692 0.184106 0.340900 0.097283            24.962978
#  lstm    52       test_all 17838        1875       0.105113   0.253283 0.537463 0.112700 0.259041  0.713410  0.366465   0.114321 0.745067 0.198226 0.354209 0.044280            27.305981
#  lstm    52      test_seen 11169        1131       0.101262   0.253283 0.558138 0.111524 0.245197  0.682116  0.395380   0.114297 0.736516 0.197886 0.352608 0.059211            27.081234
#  lstm    52       test_new  6669         744       0.111561   0.253283 0.498331 0.117220 0.282227  0.765821  0.318039   0.114355 0.758065 0.198732 0.356601 0.014956            27.647636
#  lstm    52   test_bullpen 10947        1042       0.095186   0.253283 0.537003 0.099773 0.234321  0.655917  0.394994   0.108680 0.743762 0.189649 0.342951 0.062858            27.290300
#  lstm    52   test_starter  6891         833       0.120882   0.253283 0.525368 0.125405 0.298312  0.804744  0.321144   0.122224 0.746699 0.210064 0.369315 0.006919            27.325598

# %%
# %run 04_train_gpu_models.py --model lstm --seed 62 --epochs 100
# Out:
# model  seed         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2      mcc  regression_mae_days
#  lstm    62 validation_all 24926        2087       0.083728   0.279687 0.613413 0.120609 0.196569  0.561159  0.425540   0.103475 0.764734 0.182285 0.335689 0.090835            24.906994
#  lstm    62       test_all 17838        1875       0.105113   0.279687 0.557856 0.127370 0.226242  0.633727  0.370333   0.117175 0.763733 0.203178 0.363065 0.058014            27.040337
#  lstm    62      test_seen 11169        1131       0.101262   0.279687 0.581556 0.134857 0.208824  0.596576  0.415704   0.117864 0.735632 0.203175 0.359147 0.072119            26.969343
#  lstm    62       test_new  6669         744       0.111561   0.279687 0.509495 0.119973 0.255413  0.695945  0.294347   0.116234 0.806452 0.203183 0.368641 0.027472            27.148258
#  lstm    62   test_bullpen 10947        1042       0.095186   0.279687 0.552812 0.116768 0.210876  0.599131  0.381474   0.109155 0.767754 0.191136 0.347917 0.067749            27.106848
#  lstm    62   test_starter  6891         833       0.120882   0.279687 0.555006 0.141794 0.250652  0.688685  0.352634   0.129191 0.758703 0.220786 0.384241 0.039869            26.957134

# %%
# %run 05_combine_all_results.py
# Out:
#            model         cohort  n_runs  roc_auc_mean  roc_auc_sd  pr_auc_mean  pr_auc_sd  f1_mean  recall_mean  precision_mean  brier_mean
#             lstm       test_all       3      0.538830    0.018380     0.115797   0.010376 0.197683     0.804267        0.112893    0.246772
#             lstm   test_bullpen       3      0.535461    0.018170     0.104371   0.010855 0.184136     0.802943        0.104240    0.228947
#             lstm       test_new       3      0.493566    0.018771     0.114383   0.007428 0.200331     0.821237        0.114173    0.269480
#             lstm      test_seen       3      0.562818    0.016892     0.118594   0.014125 0.196050     0.793103        0.112154    0.233212
#             lstm   test_starter       3      0.535130    0.017214     0.129649   0.010676 0.218203     0.805922        0.126311    0.275087
#             lstm validation_all       3      0.612555    0.010233     0.121779   0.001514 0.176776     0.829420        0.099179    0.214944
#           resnet       test_all       3      0.574757    0.000337     0.134854   0.002555 0.204474     0.822578        0.116779    0.093693
#           resnet   test_bullpen       3      0.573477    0.014071     0.120416   0.004229 0.189099     0.803583        0.107170    0.085759
#           resnet       test_new       3      0.522681    0.007842     0.116607   0.003736 0.204559     0.825269        0.116819    0.099879
#           resnet      test_seen       3      0.603369    0.003225     0.147613   0.002538 0.204402     0.820808        0.116757    0.089999
#           resnet   test_starter       3      0.569173    0.011670     0.154602   0.003218 0.226236     0.846339        0.130685    0.106297
#           resnet validation_all       3      0.614469    0.004402     0.121424   0.000517 0.178904     0.794122        0.100881    0.075748
#              vit       test_all       3      0.544565    0.023860     0.114876   0.009450 0.201136     0.787200        0.115309    0.189855
#              vit   test_bullpen       3      0.543884    0.035718     0.103420   0.009891 0.183555     0.786308        0.103914    0.183866
#              vit       test_new       3      0.498608    0.034660     0.110985   0.010561 0.200855     0.793907        0.114985    0.202156
#              vit      test_seen       3      0.570728    0.020666     0.118375   0.009930 0.201330     0.782788        0.115530    0.182511
#              vit   test_starter       3      0.544634    0.008496     0.132372   0.008295 0.228514     0.788315        0.133644    0.199370
#              vit validation_all       3      0.598117    0.019776     0.107749   0.003733 0.184481     0.775276        0.104754    0.161699
# xgboost_weighted       test_all       1      0.560314         NaN     0.126130        NaN 0.202716     0.796267        0.116142    0.093948
# xgboost_weighted   test_bullpen       1      0.549352         NaN     0.112504        NaN 0.184958     0.796545        0.104626    0.086070
# xgboost_weighted       test_new       1      0.497619         NaN     0.109900        NaN 0.199570     0.810484        0.113795    0.100127
# xgboost_weighted      test_seen       1      0.594190         NaN     0.136612        NaN 0.204904     0.786914        0.117787    0.090258
# xgboost_weighted   test_starter       1      0.574061         NaN     0.148672        NaN 0.230408     0.795918        0.134701    0.106462
# xgboost_weighted validation_all       1      0.609877         NaN     0.118314        NaN 0.183999     0.771921        0.104448    0.075837
