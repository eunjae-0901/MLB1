# %% [markdown]
# # Scenario 5 - Domain-engineered workload features + LightGBM (CPU)
#
# Acute:chronic workload ratios, rest-day patterns, velocity/spin/extension trend deltas, and season/career cumulative load replace the flattened 20x33 raw sequence. Train-only event weighting, Validation Platt calibration, and Validation-selected F1 threshold.

# %%
# %run 05_build_engineered_features.py
# Out:
# shape: (116432, 70)
# feature columns: ['pitches_7d', 'outs_7d', 'apps_7d', 'start_frac_7d', 'velo_7d', 'ext_7d', 'spin_7d', 'fb_share_7d', 'pitches_14d', 'outs_14d', 'apps_14d', 'start_frac_14d', 'velo_14d', 'ext_14d', 'spin_14d', 'fb_share_14d', 'pitches_28d', 'outs_28d', 'apps_28d', 'start_frac_28d', 'velo_28d', 'ext_28d', 'spin_28d', 'fb_share_28d', 'pitches_60d', 'outs_60d', 'apps_60d', 'start_frac_60d', 'velo_60d', 'ext_60d', 'spin_60d', 'fb_share_60d', 'pitches_100d', 'outs_100d', 'apps_100d', 'start_frac_100d', 'velo_100d', 'ext_100d', 'spin_100d', 'fb_share_100d', 'acwr_pitches_7_28', 'acwr_outs_7_28', 'acwr_pitches_14_60', 'velo_delta_14_100', 'ext_delta_14_100', 'spin_delta_14_100', 'fb_share_delta_14_100', 'rest_mean_100d', 'rest_std_100d', 'short_rest_count_30d', 'career_pitches', 'career_outs', 'career_apps', 'career_start_frac', 'season_pitches', 'season_outs', 'season_apps']
# regression_days           0.923062
# days_since_last_arm_il    0.686727
# rest_mean_100d            0.066021
# rest_std_100d             0.066021
# target_100d               0.058687
# pitches_100d              0.000000
# ext_100d                  0.000000
# velo_100d                 0.000000
# start_frac_100d           0.000000
# apps_100d                 0.000000
# outs_100d                 0.000000
# player_id                 0.000000
# fb_share_100d             0.000000
# fb_share_60d              0.000000
# spin_60d                  0.000000
# dtype: float64

# %%
# %run 05_train_gbm.py --seed 42
# Out:
# C:\Users\ej\anaconda3\envs\torch5090\Lib\site-packages\lightgbm\sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
#      model         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2      mcc
# gbm_seed42 validation_all 24926        2087       0.083728   0.081598 0.631653 0.123733 0.075541  0.279340  0.547180   0.115706 0.663632 0.197055 0.340831 0.110973
# gbm_seed42       test_all 17838        1875       0.105113   0.081598 0.575996 0.134817 0.093746  0.335188  0.457563   0.123468 0.682133 0.209089 0.358083 0.070433
# gbm_seed42      test_seen 11169        1131       0.101262   0.081598 0.605923 0.145325 0.089984  0.322669  0.481064   0.126262 0.696729 0.213782 0.366001 0.093257
# gbm_seed42       test_new  6669         744       0.111561   0.081598 0.521500 0.116683 0.100045  0.356153  0.418204   0.119233 0.659946 0.201974 0.346067 0.030961
# gbm_seed42   test_bullpen 10947        1042       0.095186   0.081598 0.579733 0.126164 0.085703  0.312242  0.488353   0.115274 0.655470 0.196067 0.338353 0.074351
# gbm_seed42   test_starter  6891         833       0.120882   0.081598 0.565488 0.147074 0.106521  0.371639  0.408649   0.134416 0.715486 0.226315 0.383724 0.055770

# %%
# %run 05_train_gbm.py --seed 52
# Out:
# C:\Users\ej\anaconda3\envs\torch5090\Lib\site-packages\lightgbm\sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
#      model         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2      mcc
# gbm_seed52 validation_all 24926        2087       0.083728   0.084651 0.630307 0.124492 0.075544  0.279354  0.569285   0.114950 0.618591 0.193873 0.329690 0.102080
# gbm_seed52       test_all 17838        1875       0.105113   0.084651 0.576417 0.133926 0.093747  0.335005  0.494226   0.126164 0.643200 0.210950 0.353479 0.073753
# gbm_seed52      test_seen 11169        1131       0.101262   0.084651 0.606430 0.144587 0.089993  0.322546  0.521443   0.129180 0.648983 0.215470 0.359592 0.094171
# gbm_seed52       test_new  6669         744       0.111561   0.084651 0.521420 0.116562 0.100034  0.355869  0.448643   0.121744 0.634409 0.204285 0.344375 0.038114
# gbm_seed52   test_bullpen 10947        1042       0.095186   0.084651 0.579089 0.124779 0.085728  0.312249  0.508084   0.117761 0.642035 0.199018 0.339628 0.079898
# gbm_seed52   test_starter  6891         833       0.120882   0.084651 0.568427 0.147717 0.106486  0.371155  0.472210   0.138473 0.644658 0.227977 0.372399 0.061220

# %%
# %run 05_train_gbm.py --seed 62
# Out:
# C:\Users\ej\anaconda3\envs\torch5090\Lib\site-packages\lightgbm\sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
#      model         cohort     n  n_positive  positive_rate  threshold  roc_auc   pr_auc    brier  log_loss  accuracy  precision   recall       f1       f2      mcc
# gbm_seed62 validation_all 24926        2087       0.083728   0.086951 0.632013 0.122178 0.075522  0.279043  0.591511   0.118628 0.603258 0.198268 0.331997 0.108501
# gbm_seed62       test_all 17838        1875       0.105113   0.086951 0.585103 0.139955 0.093535  0.333845  0.516313   0.129404 0.628800 0.214637 0.354885 0.080926
# gbm_seed62      test_seen 11169        1131       0.101262   0.086951 0.615489 0.153890 0.089756  0.321302  0.555108   0.135171 0.628647 0.222500 0.363348 0.106049
# gbm_seed62       test_new  6669         744       0.111561   0.086951 0.526953 0.118935 0.099863  0.354853  0.451342   0.121527 0.629032 0.203700 0.342757 0.037005
# gbm_seed62   test_bullpen 10947        1042       0.095186   0.086951 0.586029 0.131406 0.085575  0.311541  0.528638   0.120251 0.625720 0.201733 0.339937 0.084609
# gbm_seed62   test_starter  6891         833       0.120882   0.086951 0.580171 0.153802 0.106180  0.369278  0.496735   0.142857 0.632653 0.233083 0.375303 0.072354

# %%
# %run 05_combine_all_results.py
# Out:
#            model         cohort  n_runs  roc_auc_mean  roc_auc_sd  pr_auc_mean  pr_auc_sd  f1_mean  recall_mean  precision_mean  brier_mean
#       gbm_seed42       test_all       1      0.575996         NaN     0.134817        NaN 0.209089     0.682133        0.123468    0.093746
#       gbm_seed42   test_bullpen       1      0.579733         NaN     0.126164        NaN 0.196067     0.655470        0.115274    0.085703
#       gbm_seed42       test_new       1      0.521500         NaN     0.116683        NaN 0.201974     0.659946        0.119233    0.100045
#       gbm_seed42      test_seen       1      0.605923         NaN     0.145325        NaN 0.213782     0.696729        0.126262    0.089984
#       gbm_seed42   test_starter       1      0.565488         NaN     0.147074        NaN 0.226315     0.715486        0.134416    0.106521
#       gbm_seed42 validation_all       1      0.631653         NaN     0.123733        NaN 0.197055     0.663632        0.115706    0.075541
#       gbm_seed52       test_all       1      0.576417         NaN     0.133926        NaN 0.210950     0.643200        0.126164    0.093747
#       gbm_seed52   test_bullpen       1      0.579089         NaN     0.124779        NaN 0.199018     0.642035        0.117761    0.085728
#       gbm_seed52       test_new       1      0.521420         NaN     0.116562        NaN 0.204285     0.634409        0.121744    0.100034
#       gbm_seed52      test_seen       1      0.606430         NaN     0.144587        NaN 0.215470     0.648983        0.129180    0.089993
#       gbm_seed52   test_starter       1      0.568427         NaN     0.147717        NaN 0.227977     0.644658        0.138473    0.106486
#       gbm_seed52 validation_all       1      0.630307         NaN     0.124492        NaN 0.193873     0.618591        0.114950    0.075544
#       gbm_seed62       test_all       1      0.585103         NaN     0.139955        NaN 0.214637     0.628800        0.129404    0.093535
#       gbm_seed62   test_bullpen       1      0.586029         NaN     0.131406        NaN 0.201733     0.625720        0.120251    0.085575
#       gbm_seed62       test_new       1      0.526953         NaN     0.118935        NaN 0.203700     0.629032        0.121527    0.099863
#       gbm_seed62      test_seen       1      0.615489         NaN     0.153890        NaN 0.222500     0.628647        0.135171    0.089756
#       gbm_seed62   test_starter       1      0.580171         NaN     0.153802        NaN 0.233083     0.632653        0.142857    0.106180
#       gbm_seed62 validation_all       1      0.632013         NaN     0.122178        NaN 0.198268     0.603258        0.118628    0.075522
#             lstm       test_all       3      0.538830    0.018380     0.115797   0.010376 0.197683     0.804267        0.112893    0.246772
#             lstm   test_bullpen       3      0.535461    0.018170     0.104371   0.010855 0.184136     0.802943        0.104240    0.228947
#             lstm       test_new       3      0.493566    0.018771     0.114383   0.007428 0.200331     0.821237        0.114173    0.269480
#             lstm      test_seen       3      0.562818    0.016892     0.118594   0.014125 0.196050     0.793103        0.112154    0.233212
#             lstm   test_starter       3      0.535130    0.017214     0.129649   0.010676 0.218203     0.805922        0.126311    0.275087
#             lstm validation_all       3      0.612555    0.010233     0.121779   0.001514 0.176776     0.829420        0.099179    0.214944
#           resnet       test_all       3      0.574757    0.000337     0.134854   0.002555 0.204474     0.822578        0.116779    0.093693
#           resnet   test_bullpen       3      0.573477    0.014071     0.120416   0.004229 0.189099     0.803583        0.107170    0.085759
#           resnet       test_new       3      0.522681    0.007842     0.116607   0.003736 0.204559     0.825269        0.116819    0.099879
#           resnet      test_seen       3      0.603369    0.003225     0.147613   0.002538 0.204402     0.820808        0.116757    0.089999
#           resnet   test_starter       3      0.569173    0.011670     0.154602   0.003218 0.226236     0.846339        0.130685    0.106297
#           resnet validation_all       3      0.614469    0.004402     0.121424   0.000517 0.178904     0.794122        0.100881    0.075748
#   stack_ensemble       test_all       1      0.557969         NaN     0.129003        NaN 0.203424     0.750933        0.117647    0.094191
#   stack_ensemble   test_bullpen       1      0.560020         NaN     0.113857        NaN 0.190523     0.748560        0.109152    0.086177
#   stack_ensemble       test_new       1      0.497634         NaN     0.118489        NaN 0.199929     0.758065        0.115149    0.100512
#   stack_ensemble      test_seen       1      0.589953         NaN     0.137043        NaN 0.205829     0.746242        0.119378    0.090418
#   stack_ensemble   test_starter       1      0.549604         NaN     0.149409        NaN 0.222104     0.753902        0.130236    0.106924
#   stack_ensemble validation_all       1      0.633023         NaN     0.127004        NaN 0.190632     0.754672        0.109095    0.075490
#              vit       test_all       3      0.544565    0.023860     0.114876   0.009450 0.201136     0.787200        0.115309    0.189855
#              vit   test_bullpen       3      0.543884    0.035718     0.103420   0.009891 0.183555     0.786308        0.103914    0.183866
#              vit       test_new       3      0.498608    0.034660     0.110985   0.010561 0.200855     0.793907        0.114985    0.202156
#              vit      test_seen       3      0.570728    0.020666     0.118375   0.009930 0.201330     0.782788        0.115530    0.182511
#              vit   test_starter       3      0.544634    0.008496     0.132372   0.008295 0.228514     0.788315        0.133644    0.199370
#              vit validation_all       3      0.598117    0.019776     0.107749   0.003733 0.184481     0.775276        0.104754    0.161699
# xgboost_weighted       test_all       1      0.560314         NaN     0.126130        NaN 0.202716     0.796267        0.116142    0.093948
# xgboost_weighted   test_bullpen       1      0.549352         NaN     0.112504        NaN 0.184958     0.796545        0.104626    0.086070
# xgboost_weighted       test_new       1      0.497619         NaN     0.109900        NaN 0.199570     0.810484        0.113795    0.100127
# xgboost_weighted      test_seen       1      0.594190         NaN     0.136612        NaN 0.204904     0.786914        0.117787    0.090258
# xgboost_weighted   test_starter       1      0.574061         NaN     0.148672        NaN 0.230408     0.795918        0.134701    0.106462
# xgboost_weighted validation_all       1      0.609877         NaN     0.118314        NaN 0.183999     0.771921        0.104448    0.075837
