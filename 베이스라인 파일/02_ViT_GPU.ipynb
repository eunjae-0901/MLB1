# %% [markdown]
# # Kang et al. (2025) ViT reproduction
# This uses pretrained `vit_base_patch16_224`, weighted BCE (positive weight 5), and the paper-code seeds.

# %%
# %run 03_train_models.py --model vit --delta-mode official_full_period --seeds 100 200 300 400 500 600 700 800 900 1000
