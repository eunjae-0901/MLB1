# %% [markdown]
# # Kang et al. (2025) LSTM reproduction
# Run `01_build_tjs_cohort.py` and `02_build_sequences.py` first. Results are saved under `results/`.

# %%
# %run 03_train_models.py --model lstm --delta-mode official_full_period --seeds 100 200 300 400 500 600 700 800 900 1000
